# %%
import module1

print(module1.add(3, 4))
print(module1.add(5, 2))
# Out:
# 7
# 7

# %%
#from module1 import add, sub
for module1 import *   # <----- "*"가 들어가면 파일안에 있는 모든 내용을 불러온다

print(add(4, 2))
print(sub(16, 2))
# Out:
# 6
# 14
