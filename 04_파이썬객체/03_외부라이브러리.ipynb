# %%
# Do not reinvert the wheel

# %%
from faker import Faker

fake = Faker()
fake.name()
# Out:
# 'Gregg Gill MD'

# %%
fake.address()
# Out:
# '192 Madeline Manor\nPort Michael, NM 01905'

# %%
test_data = [(fake.name(), fake.address()) for i in range(30)]

print(test_data)
# Out:
# [('Justin Clark', '4636 Johnson Ports Apt. 960\nJohnsonberg, MD 47094'), ('Samantha Hall', '40163 Eric Branch\nFredmouth, IL 07315'), ('Francisco Williams', '9210 Crystal Plaza Apt. 562\nSouth Jenniferborough, FL 42232'), ('Stephanie Lawrence', '99109 Bowen Ville\nNew Ericachester, SD 77071'), ('James Mccormick', '58730 Guzman Neck Suite 030\nWrightmouth, MO 20371'), ('Kelly Rodriguez', '6501 Joe Burg\nBoydview, DC 85771'), ('Nicole Crawford', '6845 Daniel Heights Apt. 460\nLake Tiffanyfurt, LA 02502'), ('John Sanchez', '545 Scott Club\nSchaeferberg, MA 89733'), ('Ryan King', '80330 Allen Shores Suite 699\nStacyland, GU 05324'), ('John Hodges', 'PSC 5181, Box 7107\nAPO AP 82183'), ('Andrea Jacobson', '83360 Matthew Land\nTylerside, PA 43745'), ('Sarah Curtis', '97108 Robert Haven Suite 977\nSouth Robertburgh, MH 73075'), ('Sean Rodriguez', '311 Stacy Port Suite 039\nSandrafurt, NJ 46913'), ('Sophia Walsh', '455 Benjamin Haven\nEast Jeanstad, NY 14549'), ('Michael Jackson', 'PSC 4868,
# ...
